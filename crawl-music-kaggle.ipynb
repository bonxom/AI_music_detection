# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 19.0 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 12.6 MB/s eta 0:00:00a 0:00:01
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#   WARNING: The scripts f2py and numpy-config are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed numpy-2.2.6 pandas-2.3.3 pytz-2026.1.post1 tzdata-2025.3
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
# !sudo apt update
# Out:
# Get:1 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [6,794 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]33m
# Get:6 http://archive.ubuntu.com/ubuntu jammy/restricted amd64 Packages [164 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages [17.5 MB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [62.6 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,839 kB]33m
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,302 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 Packages [266 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [1,792 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [70.9 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,002 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,170 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,615 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [84.0 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Fetched 45.3 MB in 6s (7,924 kB/s)3m
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 76 packages can be upgraded. Run 'apt list --upgradable' to see them.

# %%
# !sudo apt install ffmpeg -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   alsa-topology-conf alsa-ucm-conf fontconfig fontconfig-config
#   fonts-dejavu-core gcc-12-base i965-va-driver intel-media-va-driver libaacs0
#   libaom3 libasound2 libasound2-data libass9 libasyncns0 libavc1394-0
#   libavcodec58 libavdevice58 libavfilter7 libavformat58 libavutil56 libbdplus0
#   libblas3 libbluray2 libbs2b0 libcaca0 libcairo-gobject2 libcairo2
#   libcdio-cdda2 libcdio-paranoia2 libcdio19 libchromaprint1 libcodec2-1.0
#   libdatrie1 libdav1d5 libdc1394-25 libdecor-0-0 libdecor-0-plugin-1-cairo
#   libdeflate0 libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libdrm2 libflac8 libflite1 libfontconfig1 libfreetype6
#   libfribidi0 libgbm1 libgcc-s1 libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin
#   libgdk-pixbuf2.0-common libgfortran5 libgl1 libgl1-amber-dri libgl1-mesa-dri
#   libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3
#   libgsm1 libharfbuzz0b libiec61883-0 libigdgmm12 libjack-jackd2-0 libjbig0
#   libjpeg-turbo8 libjpeg8 liblapack3 liblilv-0-0 libllvm15 libmfx1 libmp3lame0
#   libmpg123-0 libmysofa1 libnorm1 libnuma1 libogg0 libopenal-data libopenal1
#   libopenjp2-7 libopenmpt0 libopus0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess0 libpgm-5.3-0 libpixman-1-0 libpng16-16
#   libpocketsphinx3 libpostproc55 libpulse0 libquadmath0 librabbitmq4
#   libraw1394-11 librsvg2-2 librsvg2-common librubberband2 libsamplerate0
#   libsdl2-2.0-0 libsensors-config libsensors5 libserd-0-0 libshine3 libslang2
#   libsnappy1v5 libsndfile1 libsndio7.0 libsodium23 libsord-0-0 libsoxr0
#   libspeex1 libsphinxbase3 libsratom-0-0 libsrt1.4-gnutls libssh-gcrypt-4
#   libstdc++6 libswresample3 libswscale5 libthai-data libthai0 libtheora0
#   libtiff5 libtwolame0 libudfread0 libusb-1.0-0 libva-drm2 libva-x11-2 libva2
#   libvdpau1 libvidstab1.1 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx7
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwayland-server0
#   libwebp7 libwebpmux3 libx11-6 libx11-data libx11-xcb1 libx264-163
#   libx265-199 libxau6 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1
#   libxcb-xfixes0 libxcb1 libxcursor1 libxdmcp6 libxext6 libxfixes3 libxi6
#   libxinerama1 libxkbcommon0 libxrandr2 libxrender1 libxshmfence1 libxss1
#   libxv1 libxvidcore4 libxxf86vm1 libzimg2 libzmq5 libzvbi-common libzvbi0
#   mesa-va-drivers mesa-vdpau-drivers ocl-icd-libopencl1 pocketsphinx-en-us
#   shared-mime-info va-driver-all vdpau-driver-all x11-common xkb-data
# Suggested packages:
#   ffmpeg-doc i965-va-driver-shaders libasound2-plugins alsa-utils libcuda1
#   libnvcuvid1 libnvidia-encode1 libbluray-bdj jackd2 libportaudio2 opus-tools
#   pciutils pulseaudio libraw1394-doc librsvg2-bin xdg-utils lm-sensors serdi
#   sndiod sordi speex opencl-icd libvdpau-va-gl1
# The following NEW packages will be installed:
#   alsa-topology-conf alsa-ucm-conf ffmpeg fontconfig fontconfig-config
#   fonts-dejavu-core i965-va-driver intel-media-va-driver libaacs0 libaom3
#   libasound2 libasound2-data libass9 libasyncns0 libavc1394-0 libavcodec58
#   libavdevice58 libavfilter7 libavformat58 libavutil56 libbdplus0 libblas3
#   libbluray2 libbs2b0 libcaca0 libcairo-gobject2 libcairo2 libcdio-cdda2
#   libcdio-paranoia2 libcdio19 libchromaprint1 libcodec2-1.0 libdatrie1
#   libdav1d5 libdc1394-25 libdecor-0-0 libdecor-0-plugin-1-cairo libdeflate0
#   libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1
#   libdrm2 libflac8 libflite1 libfontconfig1 libfreetype6 libfribidi0 libgbm1
#   libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgfortran5 libgl1 libgl1-amber-dri libgl1-mesa-dri libglapi-mesa libglvnd0
#   libglx-mesa0 libglx0 libgme0 libgomp1 libgraphite2-3 libgsm1 libharfbuzz0b
#   libiec61883-0 libigdgmm12 libjack-jackd2-0 libjbig0 libjpeg-turbo8 libjpeg8
#   liblapack3 liblilv-0-0 libllvm15 libmfx1 libmp3lame0 libmpg123-0 libmysofa1
#   libnorm1 libnuma1 libogg0 libopenal-data libopenal1 libopenjp2-7 libopenmpt0
#   libopus0 libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0
#   libpgm-5.3-0 libpixman-1-0 libpng16-16 libpocketsphinx3 libpostproc55
#   libpulse0 libquadmath0 librabbitmq4 libraw1394-11 librsvg2-2 librsvg2-common
#   librubberband2 libsamplerate0 libsdl2-2.0-0 libsensors-config libsensors5
#   libserd-0-0 libshine3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0
#   libsodium23 libsord-0-0 libsoxr0 libspeex1 libsphinxbase3 libsratom-0-0
#   libsrt1.4-gnutls libssh-gcrypt-4 libswresample3 libswscale5 libthai-data
#   libthai0 libtheora0 libtiff5 libtwolame0 libudfread0 libusb-1.0-0 libva-drm2
#   libva-x11-2 libva2 libvdpau1 libvidstab1.1 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx7 libwayland-client0 libwayland-cursor0 libwayland-egl1
#   libwayland-server0 libwebp7 libwebpmux3 libx11-6 libx11-data libx11-xcb1
#   libx264-163 libx265-199 libxau6 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-shm0
#   libxcb-sync1 libxcb-xfixes0 libxcb1 libxcursor1 libxdmcp6 libxext6
#   libxfixes3 libxi6 libxinerama1 libxkbcommon0 libxrandr2 libxrender1
#   libxshmfence1 libxss1 libxv1 libxvidcore4 libxxf86vm1 libzimg2 libzmq5
#   libzvbi-common libzvbi0 mesa-va-drivers mesa-vdpau-drivers
#   ocl-icd-libopencl1 pocketsphinx-en-us shared-mime-info va-driver-all
#   vdpau-driver-all x11-common xkb-data
# The following packages will be upgraded:
#   gcc-12-base libgcc-s1 libstdc++6
# 3 upgraded, 189 newly installed, 0 to remove and 73 not upgraded.
# Need to get 145 MB of archives.
# After this operation, 450 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gcc-12-base amd64 12.3.0-1ubuntu1~22.04.3 [216 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libstdc++6 amd64 12.3.0-1ubuntu1~22.04.3 [699 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgcc-s1 amd64 12.3.0-1ubuntu1~22.04.3 [53.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfribidi0 amd64 1.0.8-2ubuntu3.1 [26.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libslang2 amd64 2.3.2-5build4 [468 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 shared-mime-info amd64 2.1-2 [454 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xkb-data all 2.33-1 [394 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-common all 2.4.113-2~ubuntu0.22.04.1 [5,450 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm2 amd64 2.4.113-2~ubuntu0.22.04.1 [38.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnuma1 amd64 2.0.14-3ubuntu2 [22.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpng16-16 amd64 1.6.37-3ubuntu0.4 [192 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libusb-1.0-0 amd64 2:1.0.25-1ubuntu2 [52.7 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxau6 amd64 1:1.0.9-1build5 [7,634 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdmcp6 amd64 1:1.1.3-0ubuntu5 [10.9 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb1 amd64 1.14-3ubuntu3 [49.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-data all 2:1.7.5-1ubuntu0.3 [120 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-6 amd64 2:1.7.5-1ubuntu0.3 [667 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxext6 amd64 2:1.3.4-1build1 [31.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 alsa-topology-conf all 1.2.5.1-2 [15.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasound2-data all 1.2.6.1-1ubuntu1.1 [19.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libasound2 amd64 1.2.6.1-1ubuntu1.1 [391 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 alsa-ucm-conf all 1.2.6.3-1ubuntu1.12 [43.5 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libaom3 amd64 3.3.0-1ubuntu0.1 [1,748 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva2 amd64 2.14.0-1 [65.0 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmfx1 amd64 22.3.0-1 [3,105 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva-drm2 amd64 2.14.0-1 [7,502 B]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes3 amd64 1:6.0.0-1 [11.7 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva-x11-2 amd64 2.14.0-1 [12.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau1 amd64 1.4-3build2 [27.0 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ocl-icd-libopencl1 amd64 2.2.14-3 [39.1 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavutil56 amd64 7:4.4.2-0ubuntu0.22.04.1 [290 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfreetype6 amd64 2.11.1+dfsg-1ubuntu0.3 [388 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 fontconfig-config all 2.13.1-4.2ubuntu5 [29.1 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontconfig1 amd64 2.13.1-4.2ubuntu5 [131 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-0 amd64 0.40.0-1ubuntu0.22.04.1 [264 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render0 amd64 1.14-3ubuntu3 [16.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shm0 amd64 1.14-3ubuntu3 [5,780 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrender1 amd64 1:0.9.10-1build4 [19.7 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo2 amd64 1.16.0-5ubuntu2 [628 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcodec2-1.0 amd64 1.0.1-3 [8,435 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdav1d5 amd64 0.9.2-1 [463 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsm1 amd64 1.0.19-1 [27.7 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmp3lame0 amd64 3.100-3build2 [141 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libopenjp2-7 amd64 2.4.0-6ubuntu0.4 [158 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopus0 amd64 1.3.1-0.1build2 [203 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-gobject2 amd64 1.16.0-5ubuntu2 [19.4 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-common all 2.42.8+dfsg-1ubuntu0.4 [5,546 B]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjpeg-turbo8 amd64 2.1.2-0ubuntu1 [134 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjpeg8 amd64 8c-2ubuntu10 [2,264 B]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdeflate0 amd64 1.10-2 [70.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libjbig0 amd64 2.1-3.1ubuntu0.22.04.1 [29.2 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebp7 amd64 1.2.2-2ubuntu0.22.04.2 [206 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtiff5 amd64 4.3.0-6ubuntu0.13 [185 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf-2.0-0 amd64 2.42.8+dfsg-1ubuntu0.4 [148 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 fontconfig amd64 2.13.1-4.2ubuntu5 [177 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphite2-3 amd64 1.3.14-1build2 [71.3 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz0b amd64 2.7.4-1ubuntu3.2 [353 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai-data all 0.1.29-1build1 [162 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdatrie1 amd64 0.2.13-2 [19.9 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai0 amd64 0.1.29-1build1 [19.2 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpango-1.0-0 amd64 1.50.6+ds-2ubuntu1 [230 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoft2-1.0-0 amd64 1.50.6+ds-2ubuntu1 [54.0 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangocairo-1.0-0 amd64 1.50.6+ds-2ubuntu1 [39.8 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-2 amd64 2.52.5+dfsg-3ubuntu0.2 [2,974 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsnappy1v5 amd64 1.1.8-1build3 [17.5 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu3 [57.9 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgomp1 amd64 12.3.0-1ubuntu1~22.04.3 [127 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoxr0 amd64 0.1.3-4build2 [79.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswresample3 amd64 7:4.4.2-0ubuntu0.22.04.1 [62.2 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libogg0 amd64 1.3.5-0ubuntu3 [22.9 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu4 [209 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtwolame0 amd64 0.4.0-2build2 [52.5 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbis0a amd64 1.3.7-1build2 [99.2 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisenc2 amd64 1.3.7-1build2 [82.6 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libvpx7 amd64 1.11.0-2ubuntu2.5 [1,078 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpmux3 amd64 1.2.2-2ubuntu0.22.04.2 [20.5 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libx264-163 amd64 2:0.163.3060+git5db6aa6-2build1 [591 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libx265-199 amd64 3.5-2 [1,170 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi-common all 0.2.35-19 [35.5 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi0 amd64 0.2.35-19 [262 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavcodec58 amd64 7:4.4.2-0ubuntu0.22.04.1 [5,567 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraw1394-11 amd64 2.1.2-2build2 [27.0 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libavc1394-0 amd64 0.5.4-5build2 [17.0 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libass9 amd64 1:0.15.2-1 [97.5 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libudfread0 amd64 1.1.2-1 [16.2 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbluray2 amd64 1:1.3.1-1 [159 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libchromaprint1 amd64 1.5.1-2 [28.4 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgme0 amd64 0.6.3-2 [127 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmpg123-0 amd64 1.29.3-1ubuntu0.1 [172 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisfile3 amd64 1.3.7-1build2 [17.1 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenmpt0 amd64 0.6.1-1 [592 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 librabbitmq4 amd64 0.10.0-1ubuntu2 [39.3 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrt1.4-gnutls amd64 1.4.4-4 [309 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssh-gcrypt-4 amd64 0.9.6-2ubuntu0.22.04.7 [224 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnorm1 amd64 1.5.9+dfsg-2 [221 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpgm-5.3-0 amd64 5.3.128~dfsg-2 [161 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsodium23 amd64 1.0.18-1ubuntu0.22.04.1 [164 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzmq5 amd64 4.3.4-2 [256 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavformat58 amd64 7:4.4.2-0ubuntu0.22.04.1 [1,103 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2build1 [10.2 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libflite1 amd64 2.2-3 [13.7 MB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libserd-0-0 amd64 0.30.10-2 [40.8 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsord-0-0 amd64 0.16.8-2 [21.2 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsratom-0-0 amd64 0.6.8-1 [17.0 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblilv-0-0 amd64 0.24.12-2 [42.8 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmysofa1 amd64 1.2.1~dfsg0-1 [1,157 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy/main amd64 libblas3 amd64 3.10.0-2ubuntu1 [228 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libquadmath0 amd64 12.3.0-1ubuntu1~22.04.3 [154 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgfortran5 amd64 12.3.0-1ubuntu1~22.04.3 [879 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblapack3 amd64 3.10.0-2ubuntu1 [2,504 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasyncns0 amd64 0.8-6build2 [12.8 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libflac8 amd64 1.3.3-2ubuntu0.2 [111 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsndfile1 amd64 1.0.31-2ubuntu0.2 [196 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-xcb1 amd64 2:1.7.5-1ubuntu0.3 [7,802 B]
# Get:118 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse0 amd64 1:15.99.1+dfsg1-1ubuntu2.2 [298 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsphinxbase3 amd64 0.8+5prealpha+1-13build1 [126 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpocketsphinx3 amd64 0.8.0+real5prealpha+1-14ubuntu1 [132 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpostproc55 amd64 7:4.4.2-0ubuntu0.22.04.1 [60.1 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsamplerate0 amd64 0.2.2-1build1 [1,359 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librubberband2 amd64 2.0.0-2 [90.0 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswscale5 amd64 7:4.4.2-0ubuntu0.22.04.1 [180 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvidstab1.1 amd64 1.1.0-2 [35.0 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzimg2 amd64 3.0.3+ds1-1 [241 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavfilter7 amd64 7:4.4.2-0ubuntu0.22.04.1 [1,496 kB]
# Get:128 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcaca0 amd64 0.99.beta19-2.2ubuntu4.1 [224 kB]
# Get:129 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcdio19 amd64 2.1.0-3ubuntu0.2 [63.6 kB]
# Get:130 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1build3 [16.7 kB]
# Get:131 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1build3 [15.9 kB]
# Get:132 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdc1394-25 amd64 2.2.6-4 [88.8 kB]
# Get:133 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd0 amd64 1.4.0-1 [73.6 kB]
# Get:134 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglapi-mesa amd64 23.2.1-1ubuntu3.1~22.04.3 [35.4 kB]
# Get:135 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-dri2-0 amd64 1.14-3ubuntu3 [7,206 B]
# Get:136 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-dri3-0 amd64 1.14-3ubuntu3 [6,968 B]
# Get:137 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-glx0 amd64 1.14-3ubuntu3 [25.9 kB]
# Get:138 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-present0 amd64 1.14-3ubuntu3 [5,734 B]
# Get:139 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-randr0 amd64 1.14-3ubuntu3 [18.3 kB]
# Get:140 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-sync1 amd64 1.14-3ubuntu3 [9,416 B]
# Get:141 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xfixes0 amd64 1.14-3ubuntu3 [9,996 B]
# Get:142 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxshmfence1 amd64 1.3-1build4 [5,394 B]
# Get:143 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm1 amd64 1:1.1.4-1build3 [10.4 kB]
# Get:144 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-amdgpu1 amd64 2.4.113-2~ubuntu0.22.04.1 [19.9 kB]
# Get:145 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess0 amd64 0.16-3 [19.1 kB]
# Get:146 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-intel1 amd64 2.4.113-2~ubuntu0.22.04.1 [66.7 kB]
# Get:147 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-nouveau2 amd64 2.4.113-2~ubuntu0.22.04.1 [17.5 kB]
# Get:148 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-radeon1 amd64 2.4.113-2~ubuntu0.22.04.1 [21.6 kB]
# Get:149 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libllvm15 amd64 1:15.0.7-0ubuntu0.22.04.3 [25.4 MB]
# Get:150 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsensors-config all 1:3.6.0-7ubuntu1 [5,274 B]
# Get:151 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsensors5 amd64 1:3.6.0-7ubuntu1 [26.3 kB]
# Get:152 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dri amd64 23.2.1-1ubuntu3.1~22.04.3 [8,860 kB]
# Get:153 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglx-mesa0 amd64 23.2.1-1ubuntu3.1~22.04.3 [158 kB]
# Get:154 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx0 amd64 1.4.0-1 [41.0 kB]
# Get:155 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl1 amd64 1.4.0-1 [110 kB]m
# Get:156 http://archive.ubuntu.com/ubuntu jammy/main amd64 libiec61883-0 amd64 1.2.0-4build3 [25.9 kB]
# Get:157 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjack-jackd2-0 amd64 1.9.20~dfsg-1 [293 kB]
# Get:158 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal-data all 1:1.19.1-2build3 [164 kB]
# Get:159 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio7.0 amd64 1.8.1-1.1 [29.3 kB]
# Get:160 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal1 amd64 1:1.19.1-2build3 [535 kB]
# Get:161 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-client0 amd64 1.20.0-1ubuntu0.1 [25.9 kB]
# Get:162 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-0 amd64 0.1.0-3build1 [15.1 kB]
# Get:163 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-server0 amd64 1.20.0-1ubuntu0.1 [34.3 kB]
# Get:164 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm1 amd64 23.2.1-1ubuntu3.1~22.04.3 [33.5 kB]
# Get:165 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-cursor0 amd64 1.20.0-1ubuntu0.1 [10.7 kB]
# Get:166 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-egl1 amd64 1.20.0-1ubuntu0.1 [5,582 B]
# Get:167 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor1 amd64 1:1.2.0-2build4 [20.9 kB]
# Get:168 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi6 amd64 2:1.8-1build1 [32.6 kB]
# Get:169 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama1 amd64 2:1.1.4-3 [7,382 B]
# Get:170 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon0 amd64 1.4.0-1 [125 kB]
# Get:171 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr2 amd64 2:1.5.2-1build1 [20.4 kB]
# Get:172 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-common all 1:7.7+23ubuntu2 [23.4 kB]
# Get:173 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxss1 amd64 1:1.2.3-1build2 [8,476 B]
# Get:174 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsdl2-2.0-0 amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [582 kB]
# Get:175 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shape0 amd64 1.14-3ubuntu3 [6,158 B]
# Get:176 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxv1 amd64 2:1.0.11-1build2 [11.2 kB]
# Get:177 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavdevice58 amd64 7:4.4.2-0ubuntu0.22.04.1 [87.5 kB]
# Get:178 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 ffmpeg amd64 7:4.4.2-0ubuntu0.22.04.1 [1,696 kB]
# Get:179 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libigdgmm12 amd64 22.1.2+ds1-1 [139 kB]
# Get:180 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 intel-media-va-driver amd64 22.3.1+dfsg1-1ubuntu2 [2,283 kB]
# Get:181 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libaacs0 amd64 0.11.1-1 [64.1 kB]
# Get:182 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbdplus0 amd64 0.2.0-1 [52.2 kB]
# Get:183 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-plugin-1-cairo amd64 0.1.0-3build1 [20.4 kB]
# Get:184 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.42.8+dfsg-1ubuntu0.4 [14.1 kB]
# Get:185 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-amber-dri amd64 21.3.9-0ubuntu1~22.04.1 [4,218 kB]
# Get:186 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-common amd64 2.52.5+dfsg-3ubuntu0.2 [17.7 kB]
# Get:187 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 mesa-va-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [4,100 kB]
# Get:188 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-vdpau-drivers amd64 23.2.1-1ubuntu3.1~22.04.3 [3,820 kB]
# Get:189 http://archive.ubuntu.com/ubuntu jammy/universe amd64 i965-va-driver amd64 2.4.1+dfsg1-1 [302 kB]
# Get:190 http://archive.ubuntu.com/ubuntu jammy/universe amd64 va-driver-all amd64 2.14.0-1 [3,984 B]
# Get:191 http://archive.ubuntu.com/ubuntu jammy/main amd64 vdpau-driver-all amd64 1.4-3build2 [4,510 B]
# Get:192 http://archive.ubuntu.com/ubuntu jammy/universe amd64 pocketsphinx-en-us all 0.8.0+real5prealpha+1-14ubuntu1 [27.6 MB]
# Fetched 145 MB in 31s (4,619 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
#
# (Reading database ... 15407 files and directories currently installed.)
# Preparing to unpack .../gcc-12-base_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking gcc-12-base:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04) ...
# Setting up gcc-12-base:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# (Reading database ... 15407 files and directories currently installed.)
# Preparing to unpack .../libstdc++6_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libstdc++6:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04) ...
# Setting up libstdc++6:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# (Reading database ... 15407 files and directories currently installed.)..................................] 8(Reading database ...
# Preparing to unpack .../libgcc-s1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgcc-s1:amd64 (12.3.0-1ubuntu1~22.04.3) over (12.3.0-1ubuntu1~22.04) ...
# Setting up libgcc-s1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Selecting previously unselected package libfribidi0:amd64.
# (Reading database ... 15407 files and directories currently installed.)
# Preparing to unpack .../000-libfribidi0_1.0.8-2ubuntu3.1_amd64.deb ...
# Unpacking libfribidi0:amd64 (1.0.8-2ubuntu3.1) ...
# Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../001-libslang2_2.3.2-5build4_amd64.deb ...
# Unpacking libslang2:amd64 (2.3.2-5build4) ...
# 7Progress: [  2%] [#.........................................................] 8Selecting previously unselected package shared-mime-info.
# Preparing to unpack .../002-shared-mime-info_2.1-2_amd64.deb ...
# Unpacking shared-mime-info (2.1-2) ...
# Selecting previously unselected package xkb-data.
# Preparing to unpack .../003-xkb-data_2.33-1_all.deb ...
# Unpacking xkb-data (2.33-1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../004-libdrm-common_2.4.113-2~ubuntu0.22.04.1_all.deb ...
# Unpacking libdrm-common (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../005-libdrm2_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# 7Progress: [  3%] [#.........................................................] 8Selecting previously unselected package libnuma1:amd64.
# Preparing to unpack .../006-libnuma1_2.0.14-3ubuntu2_amd64.deb ...
# Unpacking libnuma1:amd64 (2.0.14-3ubuntu2) ...
# Selecting previously unselected package libpng16-16:amd64.
# Preparing to unpack .../007-libpng16-16_1.6.37-3ubuntu0.4_amd64.deb ...
# Unpacking libpng16-16:amd64 (1.6.37-3ubuntu0.4) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../008-libusb-1.0-0_2%3a1.0.25-1ubuntu2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.25-1ubuntu2) ...
# Selecting previously unselected package libxau6:amd64.
# Preparing to unpack .../009-libxau6_1%3a1.0.9-1build5_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libxau6:amd64 (1:1.0.9-1build5) ...
# Selecting previously unselected package libxdmcp6:amd64.
# Preparing to unpack .../010-libxdmcp6_1%3a1.1.3-0ubuntu5_amd64.deb ...
# Unpacking libxdmcp6:amd64 (1:1.1.3-0ubuntu5) ...
# Selecting previously unselected package libxcb1:amd64.
# Preparing to unpack .../011-libxcb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libx11-data.
# Preparing to unpack .../012-libx11-data_2%3a1.7.5-1ubuntu0.3_all.deb ...
# Unpacking libx11-data (2:1.7.5-1ubuntu0.3) ...
# Selecting previously unselected package libx11-6:amd64.
# Preparing to unpack .../013-libx11-6_2%3a1.7.5-1ubuntu0.3_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libx11-6:amd64 (2:1.7.5-1ubuntu0.3) ...
# Selecting previously unselected package libxext6:amd64.
# Preparing to unpack .../014-libxext6_2%3a1.3.4-1build1_amd64.deb ...
# Unpacking libxext6:amd64 (2:1.3.4-1build1) ...
# Selecting previously unselected package alsa-topology-conf.
# Preparing to unpack .../015-alsa-topology-conf_1.2.5.1-2_all.deb ...
# Unpacking alsa-topology-conf (1.2.5.1-2) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../016-libasound2-data_1.2.6.1-1ubuntu1.1_all.deb ...
# Unpacking libasound2-data (1.2.6.1-1ubuntu1.1) ...
# Selecting previously unselected package libasound2:amd64.
# Preparing to unpack .../017-libasound2_1.2.6.1-1ubuntu1.1_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libasound2:amd64 (1.2.6.1-1ubuntu1.1) ...
# Selecting previously unselected package alsa-ucm-conf.
# Preparing to unpack .../018-alsa-ucm-conf_1.2.6.3-1ubuntu1.12_all.deb ...
# Unpacking alsa-ucm-conf (1.2.6.3-1ubuntu1.12) ...
# Selecting previously unselected package libaom3:amd64.
# Preparing to unpack .../019-libaom3_3.3.0-1ubuntu0.1_amd64.deb ...
# Unpacking libaom3:amd64 (3.3.0-1ubuntu0.1) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../020-libva2_2.14.0-1_amd64.deb ...
# Unpacking libva2:amd64 (2.14.0-1) ...
# 7Progress: [  7%] [####......................................................] 8Selecting previously unselected package libmfx1:amd64.
# Preparing to unpack .../021-libmfx1_22.3.0-1_amd64.deb ...
# Unpacking libmfx1:amd64 (22.3.0-1) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../022-libva-drm2_2.14.0-1_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../023-libxfixes3_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../024-libva-x11-2_2.14.0-1_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.14.0-1) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../025-libvdpau1_1.4-3build2_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.4-3build2) ...
# Selecting previously unselected package ocl-icd-libopencl1:amd64.
# Preparing to unpack .../026-ocl-icd-libopencl1_2.2.14-3_amd64.deb ...
# Unpacking ocl-icd-libopencl1:amd64 (2.2.14-3) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../027-libavutil56_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libfreetype6:amd64.
# Preparing to unpack .../028-libfreetype6_2.11.1+dfsg-1ubuntu0.3_amd64.deb ...
# Unpacking libfreetype6:amd64 (2.11.1+dfsg-1ubuntu0.3) ...
# 7Progress: [  9%] [#####.....................................................] 8Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../029-fonts-dejavu-core_2.37-2build1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-2build1) ...
# Selecting previously unselected package fontconfig-config.
# Preparing to unpack .../030-fontconfig-config_2.13.1-4.2ubuntu5_all.deb ...
# Unpacking fontconfig-config (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package libfontconfig1:amd64.
# Preparing to unpack .../031-libfontconfig1_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking libfontconfig1:amd64 (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package libpixman-1-0:amd64.
# Preparing to unpack .../032-libpixman-1-0_0.40.0-1ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 10%] [#####.....................................................] 8Unpacking libpixman-1-0:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libxcb-render0:amd64.
# Preparing to unpack .../033-libxcb-render0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-render0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-shm0:amd64.
# Preparing to unpack .../034-libxcb-shm0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-shm0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxrender1:amd64.
# Preparing to unpack .../035-libxrender1_1%3a0.9.10-1build4_amd64.deb ...
# Unpacking libxrender1:amd64 (1:0.9.10-1build4) ...
# Selecting previously unselected package libcairo2:amd64.
# Preparing to unpack .../036-libcairo2_1.16.0-5ubuntu2_amd64.deb ...
# 7Progress: [ 11%] [######....................................................] 8Unpacking libcairo2:amd64 (1.16.0-5ubuntu2) ...
# Selecting previously unselected package libcodec2-1.0:amd64.
# Preparing to unpack .../037-libcodec2-1.0_1.0.1-3_amd64.deb ...
# Unpacking libcodec2-1.0:amd64 (1.0.1-3) ...
# Selecting previously unselected package libdav1d5:amd64.
# Preparing to unpack .../038-libdav1d5_0.9.2-1_amd64.deb ...
# Unpacking libdav1d5:amd64 (0.9.2-1) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../039-libgsm1_1.0.19-1_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.19-1) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../040-libmp3lame0_3.100-3build2_amd64.deb ...
# 7Progress: [ 12%] [#######...................................................] 8Unpacking libmp3lame0:amd64 (3.100-3build2) ...
# Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../041-libopenjp2-7_2.4.0-6ubuntu0.4_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.4.0-6ubuntu0.4) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../042-libopus0_1.3.1-0.1build2_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0.1build2) ...
# Selecting previously unselected package libcairo-gobject2:amd64.
# Preparing to unpack .../043-libcairo-gobject2_1.16.0-5ubuntu2_amd64.deb ...
# Unpacking libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libgdk-pixbuf2.0-common.
# Preparing to unpack .../044-libgdk-pixbuf2.0-common_2.42.8+dfsg-1ubuntu0.4_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.42.8+dfsg-1ubuntu0.4) ...
# Selecting previously unselected package libjpeg-turbo8:amd64.
# Preparing to unpack .../045-libjpeg-turbo8_2.1.2-0ubuntu1_amd64.deb ...
# Unpacking libjpeg-turbo8:amd64 (2.1.2-0ubuntu1) ...
# Selecting previously unselected package libjpeg8:amd64.
# Preparing to unpack .../046-libjpeg8_8c-2ubuntu10_amd64.deb ...
# Unpacking libjpeg8:amd64 (8c-2ubuntu10) ...
# Selecting previously unselected package libdeflate0:amd64.
# Preparing to unpack .../047-libdeflate0_1.10-2_amd64.deb ...
# Unpacking libdeflate0:amd64 (1.10-2) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../048-libjbig0_2.1-3.1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libjbig0:amd64 (2.1-3.1ubuntu0.22.04.1) ...
# Selecting previously unselected package libwebp7:amd64.
# Preparing to unpack .../049-libwebp7_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libwebp7:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../050-libtiff5_4.3.0-6ubuntu0.13_amd64.deb ...
# Unpacking libtiff5:amd64 (4.3.0-6ubuntu0.13) ...
# Selecting previously unselected package libgdk-pixbuf-2.0-0:amd64.
# Preparing to unpack .../051-libgdk-pixbuf-2.0-0_2.42.8+dfsg-1ubuntu0.4_amd64.deb ...
# Unpacking libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package fontconfig.
# Preparing to unpack .../052-fontconfig_2.13.1-4.2ubuntu5_amd64.deb ...
# Unpacking fontconfig (2.13.1-4.2ubuntu5) ...
# Selecting previously unselected package libgraphite2-3:amd64.
# Preparing to unpack .../053-libgraphite2-3_1.3.14-1build2_amd64.deb ...
# Unpacking libgraphite2-3:amd64 (1.3.14-1build2) ...
# Selecting previously unselected package libharfbuzz0b:amd64.
# Preparing to unpack .../054-libharfbuzz0b_2.7.4-1ubuntu3.2_amd64.deb ...
# Unpacking libharfbuzz0b:amd64 (2.7.4-1ubuntu3.2) ...
# Selecting previously unselected package libthai-data.
# Preparing to unpack .../055-libthai-data_0.1.29-1build1_all.deb ...
# Unpacking libthai-data (0.1.29-1build1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libdatrie1:amd64.
# Preparing to unpack .../056-libdatrie1_0.2.13-2_amd64.deb ...
# Unpacking libdatrie1:amd64 (0.2.13-2) ...
# Selecting previously unselected package libthai0:amd64.
# Preparing to unpack .../057-libthai0_0.1.29-1build1_amd64.deb ...
# Unpacking libthai0:amd64 (0.1.29-1build1) ...
# Selecting previously unselected package libpango-1.0-0:amd64.
# Preparing to unpack .../058-libpango-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpangoft2-1.0-0:amd64.
# Preparing to unpack .../059-libpangoft2-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# 7Progress: [ 17%] [#########.................................................] 8Unpacking libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package libpangocairo-1.0-0:amd64.
# Preparing to unpack .../060-libpangocairo-1.0-0_1.50.6+ds-2ubuntu1_amd64.deb ...
# Unpacking libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Selecting previously unselected package librsvg2-2:amd64.
# Preparing to unpack .../061-librsvg2-2_2.52.5+dfsg-3ubuntu0.2_amd64.deb ...
# Unpacking librsvg2-2:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../062-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../063-libsnappy1v5_1.1.8-1build3_amd64.deb ...
# 7Progress: [ 18%] [##########................................................] 8Unpacking libsnappy1v5:amd64 (1.1.8-1build3) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../064-libspeex1_1.2~rc1.2-1.1ubuntu3_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../065-libgomp1_12.3.0-1ubuntu1~22.04.3_amd64.deb ...
# Unpacking libgomp1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../066-libsoxr0_0.1.3-4build2_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.3-4build2) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../067-libswresample3_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# 7Progress: [ 19%] [###########...............................................] 8Unpacking libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../068-libogg0_1.3.5-0ubuntu3_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.5-0ubuntu3) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../069-libtheora0_1.1.1+dfsg.1-15ubuntu4_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../070-libtwolame0_0.4.0-2build2_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.4.0-2build2) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../071-libvorbis0a_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../072-libvorbisenc2_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvpx7:amd64.
# Preparing to unpack .../073-libvpx7_1.11.0-2ubuntu2.5_amd64.deb ...
# Unpacking libvpx7:amd64 (1.11.0-2ubuntu2.5) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../074-libwebpmux3_1.2.2-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libx264-163:amd64.
# Preparing to unpack .../075-libx264-163_2%3a0.163.3060+git5db6aa6-2build1_amd64.deb ...
# Unpacking libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# Selecting previously unselected package libx265-199:amd64.
# Preparing to unpack .../076-libx265-199_3.5-2_amd64.deb ...
# Unpacking libx265-199:amd64 (3.5-2) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../077-libxvidcore4_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.7-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../078-libzvbi-common_0.2.35-19_all.deb ...
# Unpacking libzvbi-common (0.2.35-19) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libzvbi0:amd64.
# Preparing to unpack .../079-libzvbi0_0.2.35-19_amd64.deb ...
# Unpacking libzvbi0:amd64 (0.2.35-19) ...
# Selecting previously unselected package libavcodec58:amd64.
# Preparing to unpack .../080-libavcodec58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libraw1394-11:amd64.
# Preparing to unpack .../081-libraw1394-11_2.1.2-2build2_amd64.deb ...
# Unpacking libraw1394-11:amd64 (2.1.2-2build2) ...
# Selecting previously unselected package libavc1394-0:amd64.
# Preparing to unpack .../082-libavc1394-0_0.5.4-5build2_amd64.deb ...
# 7Progress: [ 23%] [#############.............................................] 8Unpacking libavc1394-0:amd64 (0.5.4-5build2) ...
# Selecting previously unselected package libass9:amd64.
# Preparing to unpack .../083-libass9_1%3a0.15.2-1_amd64.deb ...
# Unpacking libass9:amd64 (1:0.15.2-1) ...
# Selecting previously unselected package libudfread0:amd64.
# Preparing to unpack .../084-libudfread0_1.1.2-1_amd64.deb ...
# Unpacking libudfread0:amd64 (1.1.2-1) ...
# Selecting previously unselected package libbluray2:amd64.
# Preparing to unpack .../085-libbluray2_1%3a1.3.1-1_amd64.deb ...
# Unpacking libbluray2:amd64 (1:1.3.1-1) ...
# Selecting previously unselected package libchromaprint1:amd64.
# Preparing to unpack .../086-libchromaprint1_1.5.1-2_amd64.deb ...
# 7Progress: [ 24%] [#############.............................................] 8Unpacking libchromaprint1:amd64 (1.5.1-2) ...
# Selecting previously unselected package libgme0:amd64.
# Preparing to unpack .../087-libgme0_0.6.3-2_amd64.deb ...
# Unpacking libgme0:amd64 (0.6.3-2) ...
# Selecting previously unselected package libmpg123-0:amd64.
# Preparing to unpack .../088-libmpg123-0_1.29.3-1ubuntu0.1_amd64.deb ...
# Unpacking libmpg123-0:amd64 (1.29.3-1ubuntu0.1) ...
# Selecting previously unselected package libvorbisfile3:amd64.
# Preparing to unpack .../089-libvorbisfile3_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbisfile3:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libopenmpt0:amd64.
# Preparing to unpack .../090-libopenmpt0_0.6.1-1_amd64.deb ...
# 7Progress: [ 25%] [##############............................................] 8Unpacking libopenmpt0:amd64 (0.6.1-1) ...
# Selecting previously unselected package librabbitmq4:amd64.
# Preparing to unpack .../091-librabbitmq4_0.10.0-1ubuntu2_amd64.deb ...
# Unpacking librabbitmq4:amd64 (0.10.0-1ubuntu2) ...
# Selecting previously unselected package libsrt1.4-gnutls:amd64.
# Preparing to unpack .../092-libsrt1.4-gnutls_1.4.4-4_amd64.deb ...
# Unpacking libsrt1.4-gnutls:amd64 (1.4.4-4) ...
# Selecting previously unselected package libssh-gcrypt-4:amd64.
# Preparing to unpack .../093-libssh-gcrypt-4_0.9.6-2ubuntu0.22.04.7_amd64.deb ...
# Unpacking libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.7) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libnorm1:amd64.
# Preparing to unpack .../094-libnorm1_1.5.9+dfsg-2_amd64.deb ...
# Unpacking libnorm1:amd64 (1.5.9+dfsg-2) ...
# Selecting previously unselected package libpgm-5.3-0:amd64.
# Preparing to unpack .../095-libpgm-5.3-0_5.3.128~dfsg-2_amd64.deb ...
# Unpacking libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Selecting previously unselected package libsodium23:amd64.
# Preparing to unpack .../096-libsodium23_1.0.18-1ubuntu0.22.04.1_amd64.deb ...
# Unpacking libsodium23:amd64 (1.0.18-1ubuntu0.22.04.1) ...
# Selecting previously unselected package libzmq5:amd64.
# Preparing to unpack .../097-libzmq5_4.3.4-2_amd64.deb ...
# Unpacking libzmq5:amd64 (4.3.4-2) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package libavformat58:amd64.
# Preparing to unpack .../098-libavformat58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavformat58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libbs2b0:amd64.
# Preparing to unpack .../099-libbs2b0_3.1.0+dfsg-2.2build1_amd64.deb ...
# Unpacking libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Selecting previously unselected package libflite1:amd64.
# Preparing to unpack .../100-libflite1_2.2-3_amd64.deb ...
# Unpacking libflite1:amd64 (2.2-3) ...
# Selecting previously unselected package libserd-0-0:amd64.
# Preparing to unpack .../101-libserd-0-0_0.30.10-2_amd64.deb ...
# Unpacking libserd-0-0:amd64 (0.30.10-2) ...
# 7Progress: [ 28%] [################..........................................] 8Selecting previously unselected package libsord-0-0:amd64.
# Preparing to unpack .../102-libsord-0-0_0.16.8-2_amd64.deb ...
# Unpacking libsord-0-0:amd64 (0.16.8-2) ...
# Selecting previously unselected package libsratom-0-0:amd64.
# Preparing to unpack .../103-libsratom-0-0_0.6.8-1_amd64.deb ...
# Unpacking libsratom-0-0:amd64 (0.6.8-1) ...
# ...
# Unpacking mesa-vdpau-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Selecting previously unselected package i965-va-driver:amd64.
# Preparing to unpack .../185-i965-va-driver_2.4.1+dfsg1-1_amd64.deb ...
# Unpacking i965-va-driver:amd64 (2.4.1+dfsg1-1) ...
# Selecting previously unselected package va-driver-all:amd64.
# Preparing to unpack .../186-va-driver-all_2.14.0-1_amd64.deb ...
# 7Progress: [ 50%] [#############################.............................] 8Unpacking va-driver-all:amd64 (2.14.0-1) ...
# Selecting previously unselected package vdpau-driver-all:amd64.
# Preparing to unpack .../187-vdpau-driver-all_1.4-3build2_amd64.deb ...
# Unpacking vdpau-driver-all:amd64 (1.4-3build2) ...
# Selecting previously unselected package pocketsphinx-en-us.
# Preparing to unpack .../188-pocketsphinx-en-us_0.8.0+real5prealpha+1-14ubuntu1_all.deb ...
# Unpacking pocketsphinx-en-us (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libgme0:amd64 (0.6.3-2) ...
# Setting up libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.7) ...
# 7Progress: [ 51%] [#############################.............................] 8Setting up libgraphite2-3:amd64 (1.3.14-1build2) ...
# Setting up libsrt1.4-gnutls:amd64 (1.4.4-4) ...
# Setting up libpixman-1-0:amd64 (0.40.0-1ubuntu0.22.04.1) ...
# 7Progress: [ 52%] [##############################............................] 8Setting up libudfread0:amd64 (1.1.2-1) ...
# Setting up libwayland-server0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libaom3:amd64 (3.3.0-1ubuntu0.1) ...
# Setting up libpciaccess0:amd64 (0.16-3) ...
# 7Progress: [ 53%] [##############################............................] 8Setting up librabbitmq4:amd64 (0.10.0-1ubuntu2) ...
# Setting up libxau6:amd64 (1:1.0.9-1build5) ...
# Setting up libxdmcp6:amd64 (1:1.1.3-0ubuntu5) ...
# Setting up libraw1394-11:amd64 (2.1.2-2build2) ...
# 7Progress: [ 54%] [###############################...........................] 8Setting up libxcb1:amd64 (1.14-3ubuntu3) ...
# Setting up libcodec2-1.0:amd64 (1.0.1-3) ...
# Setting up libsodium23:amd64 (1.0.18-1ubuntu0.22.04.1) ...
# Setting up libmpg123-0:amd64 (1.29.3-1ubuntu0.1) ...
# 7Progress: [ 55%] [###############################...........................] 8Setting up libxcb-xfixes0:amd64 (1.14-3ubuntu3) ...
# Setting up libogg0:amd64 (1.3.5-0ubuntu3) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Setting up libshine3:amd64 (3.1.1-2) ...
# 7Progress: [ 56%] [################################..........................] 8Setting up libtwolame0:amd64 (0.4.0-2build2) ...
# Setting up libdatrie1:amd64 (0.2.13-2) ...
# Setting up libgsm1:amd64 (1.0.19-1) ...
# Setting up libxcb-render0:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 57%] [#################################.........................] 8Setting up libglvnd0:amd64 (1.4.0-1) ...
# Setting up libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Setting up libxcb-glx0:amd64 (1.14-3ubuntu3) ...
# Setting up libgdk-pixbuf2.0-common (2.42.8+dfsg-1ubuntu0.4) ...
# 7Progress: [ 58%] [#################################.........................] 8Setting up libnorm1:amd64 (1.5.9+dfsg-2) ...
# Setting up libmysofa1:amd64 (1.2.1~dfsg0-1) ...
# Setting up libxcb-shape0:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 59%] [##################################........................] 8Setting up x11-common (1:7.7+23ubuntu2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (Can't locate Term/ReadLine.pm in @INC (you may need to install the Term::ReadLine module) (@INC contains: /etc/perl /usr/local/lib/x86_64-linux-gnu/perl/5.34.0 /usr/local/share/perl/5.34.0 /usr/lib/x86_64-linux-gnu/perl5/5.34 /usr/share/perl5 /usr/lib/x86_64-linux-gnu/perl-base /usr/lib/x86_64-linux-gnu/perl/5.34 /usr/share/perl/5.34 /usr/local/lib/site_perl) at /usr/share/perl5/Debconf/FrontEnd/Readline.pm line 7.)
# debconf: falling back to frontend: Teletype
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libsensors-config (1:3.6.0-7ubuntu1) ...
# Setting up libdeflate0:amd64 (1.10-2) ...
# Setting up xkb-data (2.33-1) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libxcb-shm0:amd64 (1.14-3ubuntu3) ...
# Setting up libigdgmm12:amd64 (22.1.2+ds1-1) ...
# Setting up libgomp1:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up libcdio19:amd64 (2.1.0-3ubuntu0.2) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libxvidcore4:amd64 (2:1.3.7-1) ...
# Setting up libjbig0:amd64 (2.1-3.1ubuntu0.22.04.1) ...
# Setting up libsnappy1v5:amd64 (1.1.8-1build3) ...
# Setting up libflac8:amd64 (1.3.3-2ubuntu0.2) ...
# 7Progress: [ 62%] [###################################.......................] 8Setting up libxcb-present0:amd64 (1.14-3ubuntu3) ...
# Setting up libasound2-data (1.2.6.1-1ubuntu1.1) ...
# Setting up libblas3:amd64 (3.10.0-2ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/blas/libblas.so.3 to provide /usr/lib/x86_64-linux-gnu/libblas.so.3 (libblas.so.3-x86_64-linux-gnu) in auto mode
# Setting up libslang2:amd64 (2.3.2-5build4) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libva2:amd64 (2.14.0-1) ...
# Setting up libx11-data (2:1.7.5-1ubuntu0.3) ...
# Setting up libxcb-sync1:amd64 (1.14-3ubuntu3) ...
# Setting up libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up libfribidi0:amd64 (1.0.8-2ubuntu3.1) ...
# Setting up libopus0:amd64 (1.3.1-0.1build2) ...
# Setting up libquadmath0:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up shared-mime-info (2.1-2) ...
# Setting up intel-media-va-driver:amd64 (22.3.1+dfsg1-1ubuntu2) ...
# Setting up libpng16-16:amd64 (1.6.37-3ubuntu0.4) ...
# Setting up libvorbis0a:amd64 (1.3.7-1build2) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up libsensors5:amd64 (1:3.6.0-7ubuntu1) ...
# Setting up libaacs0:amd64 (0.11.1-1) ...
# Setting up libjpeg-turbo8:amd64 (2.1.2-0ubuntu1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up pocketsphinx-en-us (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libglapi-mesa:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libgfortran5:amd64 (12.3.0-1ubuntu1~22.04.3) ...
# Setting up libwebp7:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libxcb-dri2-0:amd64 (1.14-3ubuntu3) ...
# Setting up libbdplus0:amd64 (0.2.0-1) ...
# Setting up libnuma1:amd64 (2.0.14-3ubuntu2) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up alsa-topology-conf (1.2.5.1-2) ...
# Setting up ocl-icd-libopencl1:amd64 (2.2.14-3) ...
# Setting up libasyncns0:amd64 (0.8-6build2) ...
# Setting up libxshmfence1:amd64 (1.3-1build4) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Setting up libxcb-randr0:amd64 (1.14-3ubuntu3) ...
# Setting up libllvm15:amd64 (1:15.0.7-0ubuntu0.22.04.3) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libasound2:amd64 (1.2.6.1-1ubuntu1.1) ...
# Setting up libzimg2:amd64 (3.0.3+ds1-1) ...
# Setting up libopenjp2-7:amd64 (2.4.0-6ubuntu0.4) ...
# Setting up libx11-6:amd64 (2:1.7.5-1ubuntu0.3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libopenal-data (1:1.19.1-2build3) ...
# Setting up libthai-data (0.1.29-1build1) ...
# Setting up libvpx7:amd64 (1.11.0-2ubuntu2.5) ...
# Setting up libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libusb-1.0-0:amd64 (2:1.0.25-1ubuntu2) ...
# Setting up libdav1d5:amd64 (0.9.2-1) ...
# Setting up libmfx1:amd64 (22.3.0-1) ...
# Setting up libsamplerate0:amd64 (0.2.2-1build1) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libdrm-common (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libzvbi-common (0.2.35-19) ...
# Setting up libmp3lame0:amd64 (3.100-3build2) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libvorbisenc2:amd64 (1.3.7-1build2) ...
# Setting up libiec61883-0:amd64 (1.2.0-4build3) ...
# Setting up libserd-0-0:amd64 (0.30.10-2) ...
# Setting up libxkbcommon0:amd64 (1.4.0-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up libwayland-client0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libjpeg8:amd64 (8c-2ubuntu10) ...
# Setting up libavc1394-0:amd64 (0.5.4-5build2) ...
# Setting up libxcb-dri3-0:amd64 (1.14-3ubuntu3) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libzvbi0:amd64 (0.2.35-19) ...
# Setting up libx11-xcb1:amd64 (2:1.7.5-1ubuntu0.3) ...
# Setting up liblapack3:amd64 (3.10.0-2ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3 to provide /usr/lib/x86_64-linux-gnu/liblapack.so.3 (liblapack.so.3-x86_64-linux-gnu) in auto mode
# 7Progress: [ 78%] [#############################################.............] 8Setting up libzmq5:amd64 (4.3.4-2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.2ubuntu4.1) ...
# Setting up libxrender1:amd64 (1:0.9.10-1build4) ...
# Setting up alsa-ucm-conf (1.2.6.3-1ubuntu1.12) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libsoxr0:amd64 (0.1.3-4build2) ...
# Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1build3) ...
# Setting up fontconfig-config (2.13.1-4.2ubuntu5) ...
# Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1build3) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libxext6:amd64 (2:1.3.4-1build1) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1build3) ...
# Setting up libthai0:amd64 (0.1.29-1build1) ...
# Setting up libvorbisfile3:amd64 (1.3.7-1build2) ...
# 7Progress: [ 81%] [##############################################............] 8Setting up libfreetype6:amd64 (2.11.1+dfsg-1ubuntu0.3) ...
# Setting up libxfixes3:amd64 (1:6.0.0-1) ...
# Setting up libxinerama1:amd64 (2:1.1.4-3) ...
# Setting up libdc1394-25:amd64 (2.2.6-4) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libxv1:amd64 (2:1.0.11-1build2) ...
# Setting up libxrandr2:amd64 (2:1.5.2-1build1) ...
# Setting up libx265-199:amd64 (3.5-2) ...
# Setting up librubberband2:amd64 (2.0.0-2) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up libsndio7.0:amd64 (1.8.1-1.1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# Setting up libdrm2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libflite1:amd64 (2.2-3) ...
# Setting up libva-drm2:amd64 (2.14.0-1) ...
# Setting up libvdpau1:amd64 (1.4-3build2) ...
# Setting up libsord-0-0:amd64 (0.16.8-2) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libsratom-0-0:amd64 (0.6.8-1) ...
# Setting up libdecor-0-0:amd64 (0.1.0-3build1) ...
# Setting up libharfbuzz0b:amd64 (2.7.4-1ubuntu3.2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up libtiff5:amd64 (4.3.0-6ubuntu0.13) ...
# Setting up libxss1:amd64 (1:1.2.3-1build2) ...
# Setting up libfontconfig1:amd64 (2.13.1-4.2ubuntu5) ...
# Setting up libsndfile1:amd64 (1.0.31-2ubuntu0.2) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up libbluray2:amd64 (1:1.3.1-1) ...
# Setting up libva-x11-2:amd64 (2.14.0-1) ...
# Setting up liblilv-0-0:amd64 (0.24.12-2) ...
# Setting up libopenmpt0:amd64 (0.6.1-1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libdrm-amdgpu1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up fontconfig (2.13.1-4.2ubuntu5) ...
# Regenerating fonts cache... done.
# Setting up libdrm-nouveau2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libxi6:amd64 (2:1.8-1build1) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libgbm1:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libdrm-radeon1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libxcursor1:amd64 (1:1.2.0-2build4) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libdrm-intel1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libgl1-mesa-dri:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libopenal1:amd64 (1:1.19.1-2build3) ...
# Setting up libcairo2:amd64 (1.16.0-5ubuntu2) ...
# Setting up libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libass9:amd64 (1:0.15.2-1) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up libpostproc55:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Setting up libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
# Setting up libswscale5:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# Setting up mesa-va-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up i965-va-driver:amd64 (2.4.1+dfsg1-1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libgl1-amber-dri:amd64 (21.3.9-0ubuntu1~22.04.1) ...
# Setting up mesa-vdpau-drivers:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libglx-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libglx0:amd64 (1.4.0-1) ...
# Setting up libsphinxbase3:amd64 (0.8+5prealpha+1-13build1) ...
# Setting up libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up librsvg2-2:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libpocketsphinx3:amd64 (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libgl1:amd64 (1.4.0-1) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up va-driver-all:amd64 (2.14.0-1) ...
# Setting up libdecor-0-plugin-1-cairo:amd64 (0.1.0-3build1) ...
# Setting up librsvg2-common:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up vdpau-driver-all:amd64 (1.4-3build2) ...
# Setting up libgdk-pixbuf2.0-bin (2.42.8+dfsg-1ubuntu0.4) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libchromaprint1:amd64 (1.5.1-2) ...
# Setting up libavformat58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libavfilter7:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up libavdevice58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up ffmpeg (7:4.4.2-0ubuntu0.22.04.1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.4) ...
#
# 78

# %%
import pandas as pd
df_real = pd.read_csv("real_songs.csv")

# %%
# !pip install pathlib re shutil
# Out:
# Collecting pathlib
#   Using cached pathlib-1.0.1-py3-none-any.whl.metadata (5.1 kB)
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %%
# !pip install -U "yt-dlp[default]"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting yt-dlp[default]
#   Downloading yt_dlp-2026.3.17-py3-none-any.whl.metadata (182 kB)
# Collecting brotli (from yt-dlp[default])
#   Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp[default]) (2024.8.30)
# Collecting mutagen (from yt-dlp[default])
#   Downloading mutagen-1.47.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting pycryptodomex (from yt-dlp[default])
#   Downloading pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: requests<3,>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp[default]) (2.32.3)
# Requirement already satisfied: urllib3<3,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from yt-dlp[default]) (2.2.3)
# Collecting websockets>=13.0 (from yt-dlp[default])
#   Downloading websockets-16.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.8 kB)
# Collecting yt-dlp-ejs==0.8.0 (from yt-dlp[default])
#   Downloading yt_dlp_ejs-0.8.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp[default]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.32.2->yt-dlp[default]) (3.10)
# Downloading yt_dlp_ejs-0.8.0-py3-none-any.whl (53 kB)
# Downloading websockets-16.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (183 kB)
# Downloading brotli-1.2.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 10.5 MB/s eta 0:00:00
# Downloading mutagen-1.47.0-py3-none-any.whl (194 kB)
# Downloading pycryptodomex-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 21.1 MB/s eta 0:00:00
# Downloading yt_dlp-2026.3.17-py3-none-any.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 22.8 MB/s eta 0:00:00
# Installing collected packages: brotli, yt-dlp-ejs, yt-dlp, websockets, pycryptodomex, mutagen
#   WARNING: The script yt-dlp is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script websockets is installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts mid3cp, mid3iconv, mid3v2, moggsplit, mutagen-inspect and mutagen-pony are installed in '/home/admin/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed brotli-1.2.0 mutagen-1.47.0 pycryptodomex-3.23.0 websockets-16.0 yt-dlp-2026.3.17 yt-dlp-ejs-0.8.0
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from pathlib import Path
import re
import shutil

try:
    import yt_dlp
    from yt_dlp.utils import DownloadError
except ImportError as e:
    raise ImportError('Chưa cài yt-dlp. Chạy: pip install -U "yt-dlp[default]"') from e


OUTPUT_DIR = Path("output")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

LIMIT = None
START_FROM = "real_02996"

FFMPEG_LOCATION = shutil.which("ffmpeg")
NODE_LOCATION = shutil.which("node")
DENO_LOCATION = shutil.which("deno")
BUN_LOCATION = shutil.which("bun")
QJS_LOCATION = shutil.which("qjs") or shutil.which("quickjs")


def sanitize_filename(name: str, max_len: int = 180) -> str:
    name = str(name).strip()
    name = re.sub(r'[\\/:*?"<>|]', "_", name)
    name = re.sub(r"\s+", " ", name).strip(" .")
    if not name:
        name = "untitled"
    return name[:max_len]


def choose_unique_stem(output_dir: Path, stem: str, youtube_id: str) -> str:
    if not list(output_dir.glob(f"{stem}.*")):
        return stem

    alt_stem = f"{stem}_{youtube_id}"
    if not list(output_dir.glob(f"{alt_stem}.*")):
        return alt_stem

    return ""


def build_js_runtimes():
    if DENO_LOCATION:
        return {"deno": {"path": DENO_LOCATION}}
    if NODE_LOCATION:
        return {"node": {"path": NODE_LOCATION}}
    if BUN_LOCATION:
        return {"bun": {"path": BUN_LOCATION}}
    if QJS_LOCATION:
        return {"quickjs": {"path": QJS_LOCATION}}
    return None


def build_ydl_opts(outtmpl: str):
    if not FFMPEG_LOCATION:
        raise RuntimeError(
            "Muốn xuất MP3 thì cần ffmpeg/ffprobe. "
            "Cài ffmpeg rồi chạy lại: sudo apt install ffmpeg"
        )

    js_runtimes = build_js_runtimes()

    ydl_opts = {
        "quiet": True,
        "noprogress": True,
        "retries": 5,
        "fragment_retries": 5,
        "concurrent_fragment_downloads": 4,
        "noplaylist": True,
        "outtmpl": outtmpl,
        "windowsfilenames": False,
        "overwrites": False,
        "format": "bestaudio/best",
        "postprocessors": [{
            "key": "FFmpegExtractAudio",
            "preferredcodec": "mp3",
            "preferredquality": "192",
        }],
        "ffmpeg_location": FFMPEG_LOCATION,
    }

    if js_runtimes is not None:
        ydl_opts["js_runtimes"] = js_runtimes

    return ydl_opts, js_runtimes


def classify_error(msg: str) -> str:
    s = msg.lower()
    if (
        "video unavailable" in s
        or "this video is not available" in s
        or "private video" in s
        or "unavailable video" in s
    ):
        return "unavailable"
    if "sign in to confirm your age" in s or "age-restricted" in s:
        return "age_restricted"
    if "ffmpeg is not installed" in s:
        return "missing_ffmpeg"
    if "no supported javascript runtime could be found" in s:
        return "missing_js_runtime"
    return "other"


def download_audio(url: str, outtmpl: str):
    ydl_opts, js_runtimes = build_ydl_opts(outtmpl)
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        info = ydl.extract_info(url, download=True)
    return {
        "js_runtimes": js_runtimes,
        "info": info,
    }


name_col = "file_name" if "file_name" in df_real.columns else "filename"
if name_col not in df_real.columns:
    raise ValueError("Không tìm thấy cột tên file: cần file_name hoặc filename")
if "youtube_id" not in df_real.columns:
    raise ValueError("Không tìm thấy cột youtube_id trong df_real")

work_df = df_real[["youtube_id", name_col]].dropna().copy()
work_df["youtube_id"] = work_df["youtube_id"].astype(str).str.strip()
work_df[name_col] = work_df[name_col].astype(str).str.strip()
work_df = work_df[
    (work_df["youtube_id"] != "") & (work_df[name_col] != "")
].drop_duplicates("youtube_id")

# resume từ START_FROM nếu có
if START_FROM:
    mask = work_df[name_col].astype(str).eq(START_FROM)
    if mask.any():
        start_idx = mask.idxmax()
        work_df = work_df.loc[start_idx:]

if LIMIT is not None:
    work_df = work_df.head(LIMIT)

ok_count = 0
skip_count = 0
unavailable_count = 0
failures = []

env_logged = False

for idx, row in work_df.reset_index(drop=True).iterrows():
    youtube_id = row["youtube_id"]
    target_name = sanitize_filename(row[name_col])
    url = f"https://www.youtube.com/watch?v={youtube_id}"

    final_stem = choose_unique_stem(OUTPUT_DIR, target_name, youtube_id)
    if not final_stem:
        skip_count += 1
        continue

    outtmpl = str(OUTPUT_DIR / f"{final_stem}.%(ext)s")

    try:
        result = download_audio(url, outtmpl)

        if not env_logged:
            js_runtimes = result["js_runtimes"]
            print(
                f"Env: ffmpeg=OK, "
                f"js_runtime={list(js_runtimes.keys())[0] if js_runtimes else 'NONE'}"
            )
            if not js_runtimes:
                print("Cảnh báo: không tìm thấy JS runtime hỗ trợ (deno/node/bun/quickjs).")
            env_logged = True

        ok_count += 1
        if ok_count % 1000 == 0:
            print(f"Đã tải xong {ok_count} mẫu.")

    except DownloadError as e:
        msg = str(e)
        err_type = classify_error(msg)
        failures.append({
            "youtube_id": youtube_id,
            "name": final_stem,
            "error_type": err_type,
            "error": msg,
        })
        if err_type == "unavailable":
            unavailable_count += 1

    except Exception as e:
        failures.append({
            "youtube_id": youtube_id,
            "name": final_stem,
            "error_type": "other",
            "error": str(e),
        })

print("\n===== SUMMARY =====")
print(f"Tổng: {len(work_df)}")
print(f"Thành công: {ok_count}")
print(f"Bỏ qua (đã có file): {skip_count}")
print(f"Unavailable/private/removed: {unavailable_count}")
print(f"Lỗi khác: {len(failures) - unavailable_count}")

if failures:
    print("\nMột vài lỗi đầu tiên:")
    for item in failures[:10]:
        print(item)
# Out:
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] I5owObJNao8: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 1G4isv_Fylg: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] v5QH1wxP_lo: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] oIoZgIOgu3o: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 7yWfcNrxSxU: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] LlY90lG_Fuw: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] FoWArU2O6dY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 4iOH8V0KTVI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] FY4Qa9iLdp4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] GaT5jaGEwzc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] jxzdMPKIs2M: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] FMlXsKZpd8g: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] qXM0JdAwabU: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 9u14-QBPzSE: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] t3CoEyYEf4A: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] vOUSJSu2o84: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] RMhIC6195KU: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 61Lmk2k542k: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 0XMs-_959NM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] 205K9Pim2oE: Sign in to confirm your age. This video may be inappropriate for some users. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] ACPd7HSZkc0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] W1tzURKYFNs: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] XetchIhDXyw: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] EyxTm1OZSBI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 3KdBCFclSC0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] rOrmVMZkp3M: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] eRoBVX6uC48: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] RsELrcVNzG0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] PkLPFi4fmug: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] knP2Mmzk_Y4: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] BXPwHN0gmRM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] P6MvDQSiOBc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] gx-fg-dMROg: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] gdx7gN1UyX0: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] weuZ4ZNqxUA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] Il0S8BoucSA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] c_rMC5cC4Fk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 0XfHbil1nFw: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] GbZYtHHrmG4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] gOpFRA4YvRA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] ZRoS5ZtHYRM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] r0xTqwKMOyk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] yhJ8ctF2Q90: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 5QNQ9302XYQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 0dLezZIZOAQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] -RHRQOxubqk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] BTBqMn84vwY: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] M3gTmd8uv5I: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] yoHS2T32Z5o: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] _aBykMbRIog: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] JJ9IX4zgyLs: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 8ejLGe0GeHA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] WJ9-xN6dCW4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] uTxiMBArjEk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] Ew__nzMkRkw: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] riiut9qR3NU: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] _aNQFcNNnrE: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] tXaeLbheT0k: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] TKvzHBdcAdM: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 2HWn64016hw: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# ...
# ERROR: [youtube] OTlTAD-4tcA: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] k6M5C-oKw9k: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 75EYy4cI4_U: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] vZA5heWazIQ: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] kGpAMPS_t8U: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] szbI1vu-cCc: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] UhrIcivmcfQ: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] 40P-NkE5xnc: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] uLfYD_Kfqrs: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] JVvvLkwX0ag: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] TEJ1mM4gHWI: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] sBAN0S3rW_I: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] PLDIhqMWH00: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] VV1XWJN3nJo: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# ERROR: [youtube] e2Z0sON2UPc: Video unavailable. This video is not available
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] OqTehUMsEhk: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] PxKg2NFdBbE: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] fFlGV0897W4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] vm7eDQLoZfA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] KL7z_xfJwn4: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] No title found in player responses; falling back to title from initial data. Other metadata may also be missing
# ERROR: [youtube] fNy8llTLvuA: Sign in to confirm you’re not a bot. Use --cookies-from-browser or --cookies for the authentication. See  https://github.com/yt-dlp/yt-dlp/wiki/FAQ#how-do-i-pass-cookies-to-yt-dlp  for how to manually pass cookies. Also see  https://github.com/yt-dlp/yt-dlp/wiki/Extractors#exporting-youtube-cookies  for tips on effectively exporting YouTube cookies
